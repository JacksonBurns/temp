# %%
# %matplotlib widget

import matplotlib.pyplot as plt
# plot 3D plot
xdata = [5.97261776,2.85213619,4.25352627,1.61121718,-1.66759816,1.12235143,
2.53965639,1.15655756,0.43280967,2.34382687,1.91262812,3.09842755,
4.31578855,-0.11555349,-0.5504049,1.34876948,0.85343357,0.95713463,
1.28381575,0.83771915,0.39629435,0.66923026,-0.23474466,0.60643592,
0.12115509,-0.03274665,-1.48103186,-1.74625562,-1.85811392,-2.96930615,
-1.89553637,-1.83628989,-1.17668709,-2.46787203,-1.7721904,-2.26987618,
-1.32424087,-1.99495458,-0.37014711,-2.13762542,-2.89487494,-0.64418036,
-2.37708911,-0.87464873,-1.83151727,-2.16204595]
ydata = [-0.96670518,-1.18872682,-1.45121791,-0.88462079,-2.88017459,0.20269032,
0.26606234,-1.45733081,-0.42200878,-0.41959341,0.01433431,1.18492092,
0.91229647,-0.71538007,-0.41858658,1.16197429,0.89199568,1.01194758,
1.14384187,-0.09852875,0.21173941,-0.47430757,-0.65739731,0.54467027,
-0.64651955,-0.47826149,-1.21651564,-1.61806842,-1.66036362,-0.27696341,
0.97873169,2.3083584,0.28305786,-0.89525746,3.65711434,4.0213248,
0.14040071,-1.3799054,3.14271149,-1.28121061,-2.58141118,3.27967016,
-1.33391569,0.1866365,-1.32232949,1.18082111]
zdata = [-3.41627962,-0.84320842,-2.54362575,4.10724897,1.04780593,1.20450983,
1.39772396,1.6643681,2.30448252,-1.04564871,-0.85498273,0.11658619,
0.08811948,0.51110901,0.01767834,0.43177794,1.37178331,1.32728139,
1.34556459,3.31708755,-0.7069867,-0.60026591,-0.60412429,-0.13251373,
-0.7413518,-1.11819018,0.65226686,-0.42360565,-0.53133929,1.62299221,
-0.47517873,-0.48153925,0.39791531,-1.13988468,-1.17647393,-1.68547392,
-0.23262775,-0.68882535,0.35688313,-0.80857163,-1.25843514,0.12258462,
-0.64696611,0.42568814,-0.36725262,-1.30810552]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
colors = ['blue', 'red', 'orange', '#FF00F0','black']
ligand_names = ['1-1','1-2','1-4','1-8','1-9','1-10','1-11','1-12','1-13','2-1','2-2','2-4','2-10','2-13','2-14','2-15','2-19','2-20','2-28','2-31','3-3','3-4','3-6','3-8','3-9','3-10','3-12','4-1','4-2','4-4','4-9','4-10','4-11','4-12','4-13','4-14','4-15','4-16','4-17','4-19','4-20','4-21','4-23','4-24','4-25','4-28','4-29']
family_column = [2,2,2,2,2,3,2,3,1,2,2,2,2,2,2,2,2,2,2,2,2,2,2,1,2,2,0,1,2,2,2,2,1,2,2,2,1,1,2,1,2,2,1,2,0,2]
#plt.legend()
c = [colors[int(family)] for family in family_column] # conditional coloring
ax.scatter(xdata, ydata, zdata, \
    c=c, alpha=0.5, s=20, label=ligand_names)
# write ligand labels
for (x, y, z) in zip(xdata, ydata, zdata):
    ax.text(x,y,z,ligand_names.pop(0),zdir=(1,1,1),fontsize=10)

ax.set_xlabel('PC1', fontsize=20)
ax.set_ylabel('PC2', fontsize=20)
ax.set_zlabel('PC3', fontsize=20)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
